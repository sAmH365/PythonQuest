# %% [markdown]
# ### 1.문제 이해하는법
# * 예시를 통해, 규칙을 이해
# * 준제에 적힌 예시, 실행 예시를 모두 손/머리로 풀 수 있어야함
# * 그래도 이해 안된다면 예시를 만든다
# * 예시 만드는 법
#   * 데이터 개수를 1개 혹은 아주 작게 만듦
#   * 적용되는 규칙을 줄여본다
# * 예시를 풀어보면서 일반화 규칙을 찾고, 그 일반화 규칙을 코드로 작성
#
# ### 2. 모듈화
# * 전체 큰 문제를, 내가 다룰 수 잇는 모듈로 쪼개주는 것
# * 모듈 만드는 법
#   * input / output 결정
#   * 연산결정
#
# ### 3. 디버깅
# * 로그찍을때는 이진탐색느낌으로
#   * 중간 부분에 먼저 찍고 로직 잘 흐르는지 확인
#   * 의심 지점 로그찍어서 확인
